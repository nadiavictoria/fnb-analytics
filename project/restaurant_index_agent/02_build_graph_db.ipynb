# %%
# !pip install neo4j
# Out:
# Requirement already satisfied: neo4j in /Users/reiner/Documents/GitHub/fnb-analytics/venv/lib/python3.12/site-packages (6.1.0)
# Requirement already satisfied: pytz in /Users/reiner/Documents/GitHub/fnb-analytics/venv/lib/python3.12/site-packages (from neo4j) (2026.1.post1)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from neo4j_queries import *

# %%
from neo4j import GraphDatabase

URI = "neo4j://127.0.0.1:7687"
USERNAME = "neo4j"
PASSWORD = "password"

driver = GraphDatabase.driver(URI, auth=(USERNAME, PASSWORD))

# %%
import pandas as pd

df = pd.read_csv("dataset/03_cleaned/cleaned_restaurant.csv")

df.head()
# Out:
#                                                  url                     name  \
# 0  https://www.google.com/maps/place/$1.50+Dim+Su...      $1.50 Dim Sum Bedok
# 1  https://www.google.com/maps/place/%2301-12+Han...  #01-12 Handmade Noodles
# 2  https://www.google.com/maps/place/%2301-18+%E5...          #01-18 廣東砂煲飯。小吃
# 3  https://www.google.com/maps/place/%2301-20+%E8...          #01-20 萝卜糕 经济小吃
# 4  https://www.google.com/maps/place/%2301-35+%E5...             #01-35 健康齋素食
#
#        category  rating reviews  price  \
# 0  Hawker Stall     3.7   (479)  $1.50
# 1  Hawker Stall     4.4    (12)  $1–10
# 2  Hawker Stall     4.0     (5)  $1–10
# 3  Hawker Stall     4.7    (11)  $1–10
# 4  Hawker Stall     5.0     (1)    NaN
#
#                                              address               status  \
# 0             Block 123 Bedok North Street 2, 01-142        Open 24 hours
# 1                           4A Eunos Cres, #01-99 4A         Hawker Stall
# 2         #01-18 Geylang Bahru, Market & Food Centre         Hawker Stall
# 3                            22A Havelock Rd, #01-20  Closed · Opens 8 am
# 4  79 Telok Blangah Dr, #01-35, Telok Blangah Foo...  Closed · Opens 6 am
#
#                                              snippet  \
# 0           "Very reasonable price n very delicious"
# 1  "It tastes not bad at all, extra crispy one si...
# 2            "Very authentic and good claypot rice."
# 3                "Fried till crispy yet not greasy."
# 4                                           Takeaway
#
#                                                  img    postal         lon  \
# 0  https://lh3.googleusercontent.com/gps-cs-s/AHV...  460123.0  103.937343
# 1  https://lh3.googleusercontent.com/gps-cs-s/AHV...  402004.0  103.904256
# 2  https://lh3.googleusercontent.com/gps-cs-s/AHV...  330069.0  103.870005
# 3  https://lh3.googleusercontent.com/gps-cs-s/AHV...  161022.0  103.829623
# 4                                                NaN  100079.0  103.807618
#
#         lat                         nearest_mrt                name_norm  \
# 0  1.329199  ['bedok_north', 'bedok_reservoir']      $1.50 DIM SUM BEDOK
# 1  1.320331                           ['eunos']  #01-12 HANDMADE NOODLES
# 2  1.321463                   ['geylang_bahru']          #01-18 廣東砂煲飯。小吃
# 3  1.287971                        ['havelock']          #01-20 萝卜糕 经济小吃
# 4  1.273356                   ['telok_blangah']             #01-35 健康齋素食
#
#                                         address_norm category_clean  \
# 0             BLOCK 123 BEDOK NORTH STREET 2, 01-142   hawker stall
# 1                           4A EUNOS CRES, #01-99 4A   hawker stall
# 2         #01-18 GEYLANG BAHRU, MARKET & FOOD CENTRE   hawker stall
# 3                            22A HAVELOCK RD, #01-20   hawker stall
# 4  79 TELOK BLANGAH DR, #01-35, TELOK BLANGAH FOO...   hawker stall
#
#   category_group
# 0         hawker
# 1         hawker
# 2         hawker
# 3         hawker
# 4         hawker

# %%
def create_constraints(tx):
    tx.run("CREATE CONSTRAINT restaurant_name IF NOT EXISTS FOR (r:Restaurant) REQUIRE r.name IS UNIQUE")
    tx.run("CREATE CONSTRAINT mrt_name IF NOT EXISTS FOR (m:MRT) REQUIRE m.name IS UNIQUE")
    tx.run("CREATE CONSTRAINT category_name IF NOT EXISTS FOR (c:FoodCategory) REQUIRE c.name IS UNIQUE")

with driver.session() as session:
    session.execute_write(create_constraints)

# %%
def insert_data(tx, row):
    tx.run("""
        MERGE (r:Restaurant {name: $name})
        SET r.rating = $rating,
            r.reviews = $reviews,
            r.address = $address,
            r.lat = $lat,
            r.lon = $lon,
            r.price = $price

        MERGE (m:MRT {name: $mrt})

        MERGE (c:FoodCategory {name: $category})

        MERGE (r)-[:IS_NEAR_TO]->(m)
        MERGE (r)-[:FOOD_CATEGORIZED_AS]->(c)
    """,
    name=row["name"],
    rating=row["rating"],
    reviews=row["reviews"],
    address=row["address"],
    lat=row["lat"],
    lon=row["lon"],
    price=row["price"],
    mrt=row["nearest_mrt"],
    category=row["category_clean"]
    )

# %%
# with driver.session() as session:
#     for _, row in df.iterrows():
#         session.execute_write(insert_data, row)

# %%
search_restaurants(driver, "['eunos']", "hawker stall")
# Out:
# [{'name': '#01-12 Handmade Noodles',
#   'rating': 4.4,
#   'address': '4A Eunos Cres, #01-99 4A'},
#  {'name': '州记鸡饭烧腊', 'rating': 4.6, 'address': '29 Eunos Ave 6'},
#  {'name': '福春叻沙卤面 (Fu Chun Laksa & Lor Mee)',
#   'rating': 4.4,
#   'address': '4A Eunos Cres, #01-25'},
#  {'name': '鼎记 Ding Ji Eunos', 'rating': 1.9, 'address': '2A Eunos Cres'},
#  {'name': 'AL-AMEEN',
#   'rating': 3.1,
#   'address': 'Blk 4A Eunos Cres, #01-22 Market & Food Centre'},
#  {'name': 'ALHAM EUNOS (HAWKER CENTRE)',
#   'rating': 4.5,
#   'address': '4A Eunos Cres'},
#  {'name': 'AROMA NASI LEMAK',
#   'rating': 4.3,
#   'address': '4A Eunos Cres, #01-08'},
#  {'name': 'Chokdee Beancakes House',
#   'rating': 5.0,
#   'address': '4A Eunos Cres, #01-66/67 Market & Food Centre'},
#  {'name': 'Duck Fong Hong Kong Style Roasted Delight',
#   'rating': 2.1,
#   'address': '2A Eunos Cres'},
#  {'name': 'Eng Kee Hainanese Chicken Rice & Porridge',
#   'rating': 4.3,
#   'address': '4A Eunos Cres, #01-34 Market and Food Centre'},
#  {'name': 'Epok Epok Central',
#   'rating': 3.9,
#   'address': '4A Eunos Cres, #01-09 Market & Food Centre'},
#  {'name': 'Eunos MRT Bak Kut Teh', 'rating': 3.5, 'address': '2A Eunos Cres'},
#  {'name': 'Eunos Traditional Pancake',
#   'rating': 4.0,
#   'address': '4A Eunos Cres, #01-99 4A'},
#  {'name': 'Eunos Yong Tau Foo',
#   'rating': 3.8,
#   'address': '4A Eunos Cres, #01-36 Market and Food Centre'},
#  {'name': 'Famous Eunos Bak Chor Mee',
#   'rating': 4.1,
#   'address': '7 Eunos Cres'},
#  {'name': 'Fen Xiang Fried Kway Teow',
#   'rating': 4.0,
#   'address': '4A Eunos Cres, #01-21 Market and Food Centre'},
#  {'name': 'Geylang Homemade Carrot Cake',
#   'rating': 4.1,
#   'address': '7 Eunos Cres'},
#  {'name': 'Hope La Mian 喜旺 Xi Wang La Mian Fried Dumpling',
#   'rating': 4.3,
#   'address': '7 Eunos Cres'},
#  {'name': 'Kimly Dim Sum (2A Eunos Cresent)',
#   'rating': 3.2,
#   'address': 'Blk 2A Eunos Cres'},
#  {'name': 'Kimly Mixed Rice 金味飯莊 (Eunos Crescent)',
#   'rating': 2.8,
#   'address': 'Blk 2A Eunos Cres, #01-2431'},
#  {'name': 'Mami Midah Briyani',
#   'rating': 3.8,
#   'address': '4A Eunos Cres, #01-17 Eunos Link Food Centre'},
#  {'name': 'Man Li Seafood (7 Eunos Crescent)',
#   'rating': 3.2,
#   'address': '7 Eunos Cres, #01-2651'},
#  {'name': 'OK Chicken Rice & Humfull Laksa (Eunos)',
#   'rating': 4.6,
#   'address': '1A Eunos Cres, #01-2461 YONG LI COFFEE STATION'},
#  {'name': 'Parkson Bak Kut Teh (Eunos)',
#   'rating': 4.4,
#   'address': '7 Eunos Cres'},
#  {'name': 'Pin Xin 品馫饭庄', 'rating': 4.3, 'address': '7 Eunos Cres'},
#  {'name': 'S.J Sickander Ammal Muslim Foods',
#   'rating': 3.7,
#   'address': 'Blk 4A Eunos Cres, #01-05 Market & Food Centre'},
#  {'name': 'San Xi Hainanese Chicken Rice',
#   'rating': 3.7,
#   'address': '29 Bendemeer Rd, #01-53 Bendemeer Market & Food Centre'},
#  {'name': 'Seri Satay', 'rating': 4.3, 'address': '4A Eunos Cres, #01-15'},
#  {'name': "Shahs' Delight", 'rating': 3.9, 'address': '4A Eunos Cres, #01-06'},
#  {'name': 'Soon Seng Hot & Cold Drink',
#   'rating': 4.6,
#   'address': '4A Eunos Cres, #01-42'},
#  {'name': 'Yong Ji Cooked Food',
#   'rating': 3.8,
#   'address': '4A Eunos Cres, #01-99 4A'}]

# %%
get_graph_summary(driver)
# Out:
# {'total_nodes': 9446,
#  'restaurants': 8009,
#  'mrt_stations': 1142,
#  'categories': 295,
#  'relationships': [{'type': 'IS_NEAR_TO', 'count': 8363},
#   {'type': 'FOOD_CATEGORIZED_AS', 'count': 8120}]}

# %%
# preview_nodes(driver, "Restaurant", 5)
preview_nodes(driver, "MRT", 5)
# preview_nodes(driver, "FoodCategory", 5)
# Out:
# [<Node element_id='4:ac4faac0-f38c-4002-9808-3ed919f7742f:1' labels=frozenset({'MRT'}) properties={'name': "['bedok_north', 'bedok_reservoir']"}>,
#  <Node element_id='4:ac4faac0-f38c-4002-9808-3ed919f7742f:4' labels=frozenset({'MRT'}) properties={'name': "['eunos']"}>,
#  <Node element_id='4:ac4faac0-f38c-4002-9808-3ed919f7742f:6' labels=frozenset({'MRT'}) properties={'name': "['geylang_bahru']"}>,
#  <Node element_id='4:ac4faac0-f38c-4002-9808-3ed919f7742f:8' labels=frozenset({'MRT'}) properties={'name': "['havelock']"}>,
#  <Node element_id='4:ac4faac0-f38c-4002-9808-3ed919f7742f:10' labels=frozenset({'MRT'}) properties={'name': "['telok_blangah']"}>]

# %%
check_isolated_restaurants(driver)
# Out:
# []
